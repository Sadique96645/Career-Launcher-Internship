# %%
# Import all the important library.
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
df = pd.read_csv("../Intership/Module1Solutions.csv")
df.head()
# Out:
#    Unnamed: 0   Symbol Series        Date  Prev Close  Open Price  High Price  \
# 0           0  M&amp;M     EQ  2017-05-15     1367.85      1373.0     1386.65
# 1           1  M&amp;M     EQ  2017-05-16     1375.65      1377.0     1380.50
# 2           2  M&amp;M     EQ  2017-05-17     1366.35      1363.0     1384.35
# 3           3  M&amp;M     EQ  2017-05-18     1378.80      1369.0     1372.00
# 4           4  M&amp;M     EQ  2017-05-19     1352.85      1350.0     1357.60
#
#    Low Price  Last Price  Close Price  ...  Total Traded Quantity  \
# 0     1370.0     1374.80      1375.65  ...                 558190
# 1     1363.1     1364.15      1366.35  ...                 516012
# 2     1360.4     1379.00      1378.80  ...                 920884
# 3     1347.5     1347.50      1352.85  ...                1217846
# 4     1328.5     1338.20      1333.40  ...                 976742
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  Year  \
# ...

# %% [markdown]
# ### 2.1 Load the week2.csv file into a dataframe. What is the type of the Date column? Make sure it is of type datetime64. Convert the Date column to the index of the dataframe.

# %%
df.Date.dtype
# Out:
# dtype('O')

# %%
df['Date'] = pd.to_datetime(df.Date)
df.Date.dtype
# Out:
# dtype('<M8[ns]')

# %%
df.set_index('Date', inplace = True)
df
# Out:
#             Unnamed: 0   Symbol Series  Prev Close  Open Price  High Price  \
# Date
# 2017-05-15           0  M&amp;M     EQ     1367.85     1373.00     1386.65
# 2017-05-16           1  M&amp;M     EQ     1375.65     1377.00     1380.50
# 2017-05-17           2  M&amp;M     EQ     1366.35     1363.00     1384.35
# 2017-05-18           3  M&amp;M     EQ     1378.80     1369.00     1372.00
# 2017-05-19           4  M&amp;M     EQ     1352.85     1350.00     1357.60
# 2017-05-22           5  M&amp;M     EQ     1333.40     1340.15     1341.95
# 2017-05-23           6  M&amp;M     EQ     1306.25     1315.00     1338.35
# 2017-05-24           7  M&amp;M     EQ     1331.75     1331.50     1338.80
# 2017-05-25           8  M&amp;M     EQ     1308.65     1311.00     1335.90
# 2017-05-26           9  M&amp;M     EQ     1327.50     1334.00     1348.90
# 2017-05-29          10  M&amp;M     EQ     1340.85     1345.00     1375.75
# ...

# %% [markdown]
# ####  Plot the closing price of each of the days for the entire time frame to get an idea of what the general outlook of the stock is

# %%
df['Close Price'].plot(label= 'Mahindra & Mahindra',title = 'Closing Price of share on everyday')
plt.legend()

# %% [markdown]
# ### 2.2Display a stem plot of the daily change in of the stock price in percentage. This column was calculated in module 1 and should be already available in week2.csv. Observe whenever there's a large change.

# %%
df = df.reset_index()
plt.figure(figsize=(20,10))
plt.stem(df['Date'],df['Day_Perc_Change'])
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# ### 2.3  Plot the daily volumes as well and compare the percentage stem plot to it. Document your analysis of the relationship between volume and daily percentage change.

# %%
plt.figure(figsize=(20,10))
plt.stem(df['Date'],df['Total Traded Quantity'])
plt.ylabel('Volume of Share Traded')
plt.xlabel('Date')
plt.show()
plt.figure(figsize=(20,10))
plt.stem(df['Date'],df['Day_Perc_Change'])
plt.ylabel('daily percentage change of Price')
plt.xlabel('Date')
plt.show()

# %%
# Documentation:-
# Analysis: The positive hills of Day_Perc_Change vs Date plot matches slightly with the Total Traded Quantity vs Date plot.
# Inference: It implies that whenever the positive daily percentages increases our total traded quantity also rises by somewhat the same amount.
# And since the daily changing percentage depends upon the closing prices of each day hence closing prices play a major in the increase of the total traded quantity

# %% [markdown]
# ### 2.4  We had created a Trend column in module 1. We want to see how often each Trend type occurs. This can be seen as a pie chart, with each sector representing the percentage of days each trend occurs. Plot a pie chart for all the 'Trend' to know about relative frequency of each trend. You can use the groupby function with the trend column to group all days with the same trend into a single group before plotting the pie chart. From the grouped data, create a BAR plot of average & median values of the 'Total Traded Quantity' by Trend type.

# %%
df.Trend.value_counts(sort=False).plot.pie( autopct='%1.1f%%',startangle=90, shadow=False, labels=df['Trend'], legend = False, fontsize=14)
plt.show()

# %%
plt.figure(figsize=(20,10))
df.groupby('Trend')['Total Traded Quantity'].median().plot(kind='bar')
plt.grid(True)

# %% [markdown]
# ### 2.5  Plot the daily return (percentage) distribution as a histogram. Histogram analysis is one of the most fundamental methods of exploratory data analysis. In this case, it'd return a frequency plot of various values of percentage changes .

# %%
plt.figure(figsize=(20,10))
plt.hist(df['Day_Perc_Change'])
plt.show()

# %% [markdown]
# ### 2.6
# We next want to analyse how the behaviour of different stocks are correlated. The correlation is performed on the percentage change of the stock price instead of the stock price.
#
# Load any 5 stocks of your choice into 5 dataframes. Retain only rows for which ‘Series’ column has value ‘EQ’.

# %%
Adani = pd.read_csv(r'C:\Users\sadiq\Downloads\Intership\Large_Cap\Large_Cap\ADANIPORTS.csv')
LT = pd.read_csv(r'C:\Users\sadiq\Downloads\Intership\Large_Cap\Large_Cap\LT.csv')
MARUTI = pd.read_csv(r'C:\Users\sadiq\Downloads\Intership\Large_Cap\Large_Cap\MARUTI.csv')
M_M = pd.read_csv(r'C:\Users\sadiq\Downloads\Intership\Large_Cap\Large_Cap\M&M.csv')
CIPLA = pd.read_csv(r'C:\Users\sadiq\Downloads\Intership\Large_Cap\Large_Cap\CIPLA.csv')

# %%
Adani = Adani[Adani['Series']=='EQ']
Adani
# Out:
#          Symbol Series       Date  Prev Close  Open Price  High Price  \
# 0    ADANIPORTS     EQ  15-May-17      357.95      359.00      359.75
# 1    ADANIPORTS     EQ  16-May-17      356.20      354.20      358.15
# 2    ADANIPORTS     EQ  17-May-17      354.50      354.50      354.80
# 3    ADANIPORTS     EQ  18-May-17      348.55      344.30      359.55
# 4    ADANIPORTS     EQ  19-May-17      347.90      349.05      352.50
# 5    ADANIPORTS     EQ  22-May-17      349.45      352.40      357.40
# 6    ADANIPORTS     EQ  23-May-17      354.45      354.80      355.60
# 7    ADANIPORTS     EQ  24-May-17      331.65      333.40      342.95
# 8    ADANIPORTS     EQ  25-May-17      339.65      344.90      346.25
# 9    ADANIPORTS     EQ  26-May-17      340.75      342.40      351.00
# 10   ADANIPORTS     EQ  29-May-17      348.00      347.80      348.35
# 11   ADANIPORTS     EQ  30-May-17      327.80      328.40      342.90
# ...

# %%
LT = LT[LT['Series']=='EQ']
LT
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0       LT     EQ  15-May-2017     1740.60     1748.60     1751.55    1736.50
# 1       LT     EQ  16-May-2017     1742.40     1747.00     1748.25    1727.55
# 2       LT     EQ  17-May-2017     1740.70     1743.90     1764.00    1730.50
# 3       LT     EQ  18-May-2017     1755.45     1739.65     1750.10    1716.40
# 4       LT     EQ  19-May-2017     1722.60     1729.00     1734.00    1697.55
# 5       LT     EQ  22-May-2017     1724.55     1733.00     1759.00    1729.00
# 6       LT     EQ  23-May-2017     1751.95     1755.00     1764.90    1727.40
# 7       LT     EQ  24-May-2017     1740.75     1742.10     1756.90    1677.60
# 8       LT     EQ  25-May-2017     1684.45     1692.00     1775.00    1692.00
# 9       LT     EQ  26-May-2017     1768.85     1770.00     1799.00    1753.85
# 10      LT     EQ  29-May-2017     1787.60     1783.90     1809.95    1766.00
# ...

# %%
MARUTI = MARUTI[MARUTI['Series']=='EQ']
MARUTI
# Out:
#      Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    MARUTI     EQ  15-May-2017     6730.20     6759.40     6839.10
# 1    MARUTI     EQ  16-May-2017     6823.90     6850.00     6977.55
# 2    MARUTI     EQ  17-May-2017     6953.95     6950.00     6979.00
# 3    MARUTI     EQ  18-May-2017     6958.20     6918.30     6948.00
# 4    MARUTI     EQ  19-May-2017     6831.05     6854.80     6893.90
# 5    MARUTI     EQ  22-May-2017     6790.55     6803.95     6843.95
# 6    MARUTI     EQ  23-May-2017     6701.70     6765.00     6910.00
# 7    MARUTI     EQ  24-May-2017     6878.85     6903.00     6912.55
# 8    MARUTI     EQ  25-May-2017     6869.65     6879.95     7018.00
# 9    MARUTI     EQ  26-May-2017     6985.70     6971.15     7085.05
# 10   MARUTI     EQ  29-May-2017     7064.80     7050.00     7197.80
# 11   MARUTI     EQ  30-May-2017     7134.45     7134.45     7206.60
# 12   MARUTI     EQ  31-May-2017     7147.50     7138.00     7248.00
# ...

# %%
M_M = M_M[M_M['Series']=='EQ']
M_M
# Out:
#       Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    M&amp;M     EQ  15-May-2017     1367.85     1373.00     1386.65
# 1    M&amp;M     EQ  16-May-2017     1375.65     1377.00     1380.50
# 2    M&amp;M     EQ  17-May-2017     1366.35     1363.00     1384.35
# 3    M&amp;M     EQ  18-May-2017     1378.80     1369.00     1372.00
# 4    M&amp;M     EQ  19-May-2017     1352.85     1350.00     1357.60
# 5    M&amp;M     EQ  22-May-2017     1333.40     1340.15     1341.95
# 6    M&amp;M     EQ  23-May-2017     1306.25     1315.00     1338.35
# 7    M&amp;M     EQ  24-May-2017     1331.75     1331.50     1338.80
# 8    M&amp;M     EQ  25-May-2017     1308.65     1311.00     1335.90
# 9    M&amp;M     EQ  26-May-2017     1327.50     1334.00     1348.90
# 10   M&amp;M     EQ  29-May-2017     1340.85     1345.00     1375.75
# 11   M&amp;M     EQ  30-May-2017     1360.05     1364.00     1379.00
# 12   M&amp;M     EQ  31-May-2017     1361.10     1392.50     1448.50
# ...

# %%
CIPLA = CIPLA[CIPLA['Series']=='EQ']
CIPLA
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0    CIPLA     EQ  15-May-17      567.95      567.00      572.45     561.00
# 1    CIPLA     EQ  16-May-17      569.00      566.65      570.00     564.00
# 2    CIPLA     EQ  17-May-17      565.60      565.10      566.00     560.05
# 3    CIPLA     EQ  18-May-17      562.35      559.30      564.95     556.80
# 4    CIPLA     EQ  19-May-17      560.10      561.30      566.65     558.65
# 5    CIPLA     EQ  22-May-17      564.95      567.00      567.70     553.10
# 6    CIPLA     EQ  23-May-17      563.10      558.60      558.80     531.25
# 7    CIPLA     EQ  24-May-17      533.20      531.00      536.35     514.00
# 8    CIPLA     EQ  25-May-17      519.65      522.00      525.00     496.40
# 9    CIPLA     EQ  26-May-17      504.00      483.00      504.75     480.20
# 10   CIPLA     EQ  29-May-17      488.90      492.00      507.50     488.90
# ...

# %% [markdown]
# Create a single dataframe which contains the ‘Closing Price’ of each stock. This dataframe should hence have five columns. Rename each column to the name of the stock that is contained in the column.

# %%
columns = ['Adani','LT','MARUTI','CIPLA','M_M']
close_prices_data = pd.DataFrame(columns = columns)
close_prices_data['Adani'] = Adani['Close Price']
close_prices_data['LT'] = LT['Close Price']
close_prices_data['MARUTI'] = MARUTI['Close Price']
close_prices_data['M_M'] = M_M['Close Price']
close_prices_data['CIPLA'] = CIPLA['Close Price']
close_prices_data.dropna()
# Out:
#       Adani       LT   MARUTI   CIPLA      M_M
# 0    356.20  1742.40  6823.90  569.00  1375.65
# 1    354.50  1740.70  6953.95  565.60  1366.35
# 2    348.55  1755.45  6958.20  562.35  1378.80
# 3    347.90  1722.60  6831.05  560.10  1352.85
# 4    349.45  1724.55  6790.55  564.95  1333.40
# 5    354.45  1751.95  6701.70  563.10  1306.25
# 6    331.65  1740.75  6878.85  533.20  1331.75
# 7    339.65  1684.45  6869.65  519.65  1308.65
# 8    340.75  1768.85  6985.70  504.00  1327.50
# 9    348.00  1787.60  7064.80  488.90  1340.85
# 10   327.80  1782.40  7134.45  505.35  1360.05
# 11   340.35  1767.55  7147.50  510.50  1361.10
# 12   339.00  1760.70  7211.00  516.35  1416.95
# 13   349.20  1792.80  7146.60  515.55  1425.25
# 14   357.90  1784.00  7114.70  530.05  1418.50
# 15   361.05  1804.90  7125.70  534.80  1423.70
# 16   361.45  1775.15  7112.10  534.65  1411.45
# 17   359.10  1788.60  7205.70  540.20  1431.90
# 18   359.15  1774.25  7249.50  550.15  1417.50
# ...

# %% [markdown]
# Create a new dataframe which is a percentage change of the values in the previous dataframe. Drop Nan’s from this dataframe

# %%
pct_change_data = close_prices_data.pct_change().fillna(0)
pct_change_data.dropna()
# Out:
#         Adani        LT    MARUTI     CIPLA       M_M
# 0    0.000000  0.000000  0.000000  0.000000  0.000000
# 1   -0.004773 -0.000976  0.019058 -0.005975 -0.006760
# 2   -0.016784  0.008474  0.000611 -0.005746  0.009112
# 3   -0.001865 -0.018713 -0.018273 -0.004001 -0.018821
# 4    0.004455  0.001132 -0.005929  0.008659 -0.014377
# 5    0.014308  0.015888 -0.013084 -0.003275 -0.020361
# 6   -0.064325 -0.006393  0.026434 -0.053099  0.019522
# 7    0.024122 -0.032342 -0.001337 -0.025413 -0.017346
# 8    0.003239  0.050105  0.016893 -0.030116  0.014404
# 9    0.021277  0.010600  0.011323 -0.029960  0.010056
# 10  -0.058046 -0.002909  0.009859  0.033647  0.014319
# 11   0.038286 -0.008331  0.001829  0.010191  0.000772
# 12  -0.003967 -0.003875  0.008884  0.011459  0.041033
# 13   0.030088  0.018231 -0.008931 -0.001549  0.005858
# 14   0.024914 -0.004909 -0.004464  0.028125 -0.004736
# 15   0.008801  0.011715  0.001546  0.008961  0.003666
# ...

# %% [markdown]
# Using seaborn, analyse the correlation between the percentage changes in the five stocks. This is extremely useful for a fund manager to design a diversified portfolio. To know more, check out these resources on correlation and diversification.

# %%
import seaborn as sns

sns.set(color_codes=True)
#sns.pairplot(pct_change_dataFrame)
sns.pairplot(pct_change_data, palette="husl")

# %% [markdown]
# ### 2.7
# Volatility is the change in variance in the returns of a stock over a specific period of time.Do give the following documentation on volatility a read. You have already calculated the percentage changes in several stock prices. Calculate the 7 day rolling average of the percentage change of any of the stock prices, then compute the standard deviation (which is the square root of the variance) and plot the values. Note: pandas provides a rolling() function for dataframes and a std() function also which you can use.

# %%
rolling_avg_Adani = pct_change_data['Adani'].rolling(7).mean()
rolling_avg_Adani
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6     -0.009855
# 7     -0.006409
# 8     -0.005264
# 9      0.000173
# 10    -0.007853
# 11    -0.003020
# 12    -0.005631
# 13     0.007857
# 14     0.007970
# 15     0.008765
# 16     0.005884
# 17     0.013247
# 18     0.007798
# 19     0.008643
# 20     0.003153
# 21     0.000615
# 22    -0.000603
# 23    -0.000562
# 24     0.001617
# 25     0.005786
# 26     0.006215
# 27     0.005238
# 28     0.004024
# 29     0.002438
#          ...
# 465   -0.000259
# 466    0.004852
# 467    0.004930
# 468    0.008793
# 469    0.007484
# 470    0.008112
# 471    0.004572
# 472    0.008075
# 473   -0.000450
# 474    0.001031
# 475    0.000212
# 476   -0.000029
# 477    0.001440
# 478    0.002632
# 479    0.003194
# 480    0.004028
# 481    0.003910
# 482    0.002823
# 483    0.004624
# 484    0.001378
# 485    0.001777
# 486   -0.001014
# 487    0.001737
# 488   -0.001355
# ...

# %%
std_Adani = rolling_avg_Adani.fillna(0).std()
std_Adani
# Out:
# 0.0066475515323852164

# %%
crrDate = pd.to_datetime(Adani['Date'])
crrLis = crrDate.tolist()
plt.figure(figsize=(20,10))
plt.plot(crrLis,rolling_avg_Adani.fillna(0).tolist())
plt.show()

# %% [markdown]
# ### 2.8
# Calculate the volatility for the Nifty index and compare the 2. This leads us to a useful indicator known as 'Beta' ( We'll be covering this in length in Module 3)

# %%
nifty_data = pd.read_csv(r'C:\Users\sadiq\Downloads\Intership\Nifty50\Nifty50\Nifty50.csv')
nifty_data
# Out:
#           Date      Open      High       Low     Close  Shares Traded  \
# 0    15-May-17   9433.55   9449.25   9423.10   9445.40      145163953
# 1    16-May-17   9461.00   9517.20   9456.35   9512.25      171709433
# 2    17-May-17   9517.60   9532.60   9486.10   9525.75      211856040
# 3    18-May-17   9453.20   9489.10   9418.10   9429.45      199340647
# 4    19-May-17   9469.90   9505.75   9390.75   9427.90      259861396
# 5    22-May-17   9480.25   9498.65   9427.90   9438.25      202874757
# 6    23-May-17   9445.05   9448.05   9370.00   9386.15      231345629
# 7    24-May-17   9410.90   9431.90   9341.65   9360.55      218265181
# 8    25-May-17   9384.05   9523.30   9379.20   9509.75      298147347
# 9    26-May-17   9507.75   9604.90   9495.40   9595.10      225647631
# 10   29-May-17   9560.05   9637.75   9547.70   9604.90      242266034
# 11   30-May-17   9590.65   9635.30   9581.20   9624.55      199894193
# ...

# %%
nif_close_price = nifty_data['Close']
nif_change = nif_close_price.pct_change().fillna(0).rolling(7).mean().fillna(0)
nifDate = pd.to_datetime(nifty_data['Date'])
nifDate = nifDate.tolist()
plt.figure(figsize=(20,10))

LT_Date = pd.to_datetime(LT['Date'])
LT_Lis = LT_Date.tolist()
LT_close_price = LT['Close Price']
LT_change = LT_close_price.pct_change().fillna(0).rolling(7).mean().fillna(0)
plt.figure(figsize=(20,10))
plt.plot(LT_Lis,rolling_avg_Adani.fillna(0).tolist())

plt.title("Volatility of NIFTY with respect to LT and ADANI")
plt.plot(nifDate,nif_change.tolist(),label = 'nifty')
plt.plot(crrLis,rolling_avg_Adani.fillna(0).tolist(),label = 'Adani')
plt.plot(LT_Lis,LT_change,label = 'LT')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 2.9
# Trade Calls - Using Simple Moving Averages. Study about moving averages here.Plot the 21 day and 34 day Moving average with the average price and decide a Call ! Call should be buy whenever the smaller moving average (21) crosses over longer moving average (34) AND the call should be sell whenever smaller moving average crosses under longer moving average. One of the most widely used technical indicators.

# %%
# we will use tcs stocks for applying buy/sell signals
plt.figure(figsize=(20,10))
plt.plot(LT_Lis,LT_change,label = 'LT')
plt.legend(loc='upper left')
plt.show()

# %%
#making short and long signals
short_window = 21
long_window = 34

signals = pd.DataFrame(index=LT.index)
signals['signal'] = 0.0

#SMA of Short Window
signals['short_mavg'] = LT['Close Price'].rolling(window=short_window, min_periods=1,center=False).mean()

#SMA of Long Window
signals['long_mavg'] = LT['Close Price'].rolling(window=long_window,min_periods=1, center=False).mean()

#Create signals
signals['signal'][short_window:] = np.where(signals['short_mavg'][short_window:] > signals['long_mavg'][short_window:], 1.0,0.0)

#Generate trading orders
signals['positions'] = signals['signal'].diff()
print(signals)
# Out:
#      signal   short_mavg    long_mavg  positions
# 0       0.0  1742.400000  1742.400000        NaN
# 1       0.0  1741.550000  1741.550000        0.0
# 2       0.0  1746.183333  1746.183333        0.0
# 3       0.0  1740.287500  1740.287500        0.0
# 4       0.0  1737.140000  1737.140000        0.0
# 5       0.0  1739.608333  1739.608333        0.0
# 6       0.0  1739.771429  1739.771429        0.0
# 7       0.0  1732.856250  1732.856250        0.0
# 8       0.0  1736.855556  1736.855556        0.0
# 9       0.0  1741.930000  1741.930000        0.0
# 10      0.0  1745.609091  1745.609091        0.0
# 11      0.0  1747.437500  1747.437500        0.0
# 12      0.0  1748.457692  1748.457692        0.0
# 13      0.0  1751.625000  1751.625000        0.0
# 14      0.0  1753.783333  1753.783333        0.0
# 15      0.0  1756.978125  1756.978125        0.0
# 16      0.0  1758.047059  1758.047059        0.0
# 17      0.0  1759.744444  1759.744444        0.0
# ...

# %%
# Initialize the plot figure
fig = plt.figure(figsize=(20,15))

#Add a subplot and label for y-axis
ax1 = fig.add_subplot(111, ylabel='Price')

#Plot the closing price
LT['Close Price'].plot(ax=ax1, color='black', lw=2.)

#plot the short and long moving averages
signals[['short_mavg', 'long_mavg']].plot(ax=ax1, lw=2.)

#Plot the buy signals
ax1.plot(signals.loc[signals.positions == 1.0].index, signals.short_mavg[signals.positions == 1.0], '^' , markersize=20,color='g')

#Plot the sell signals
ax1.plot(signals.loc[signals.positions == -1.0].index, signals.short_mavg[signals.positions == -1.0], 'v' , markersize=20,color='r')

plt.show()

# %% [markdown]
# ### 2.10 Trade Calls - Using Bollinger Bands¶
# Plot the bollinger bands for this stock - the duration of 14 days and 2 standard deviations away from the average The bollinger bands comprise the following data points- The 14 day rolling mean of the closing price (we call it the average) Upper band which is the rolling mean + 2 standard deviations away from the average. Lower band which is the rolling mean - 2 standard deviations away from the average. Average Daily stock price. Bollinger bands are extremely reliable , with a 95% accuracy at 2 standard deviations , and especially useful in sideways moving market. Observe the bands yourself , and analyse the accuracy of all the trade signals provided by the bollinger bands. Save to a new csv file.

# %%
symbol = 'M&M'

# read csv file, use date as index and read close as a column
df = pd.read_csv(r'C:\Users\sadiq\Downloads\Intership\M&M.csv'.format(symbol), index_col='Date',parse_dates=True, usecols=['Date', 'Close Price'],na_values='nan')

# rename the column header with symbol name
df = df.rename(columns={'Close Price': symbol})
df.dropna(inplace=True)

# calculate Simple Moving Average with 14 days window
sma = df.rolling(window=14).mean()

# calculate the standar deviation
rstd = df.rolling(window=14).std()

upper_band = sma + 2 * rstd
upper_band = upper_band.rename(columns={symbol: 'upper'})
lower_band = sma - 2 * rstd
lower_band = lower_band.rename(columns={symbol: 'lower'})
df = df.join(upper_band).join(lower_band)
ax = df.plot(title='{} Price and BB'.format(symbol))
ax.set_xlabel('Date')
ax.set_ylabel('SMA and BB')
ax.grid()
plt.show()
